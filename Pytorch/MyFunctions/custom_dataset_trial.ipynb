# %%
from CustomDataset import ImageLoader
from torchvision import transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
data = ImageLoader(img_folder = 'weather', target_size = (256,256))

# %%
labelmap = data.labelmap
image, label = data[np.random.randint(0, data.len)]

plt.title(labelmap[label])
plt.imshow(image)
plt.show()
