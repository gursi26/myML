# %%
import tensorflow as tf

# %%
conda list
# Out:
# # packages in environment at /Users/gursi/opt/anaconda3/envs/Kerasflow:
# #
# # Name                    Version                   Build  Channel
# absl-py                   0.11.0                   pypi_0    pypi
# appnope                   0.1.2           py38hecd8cb5_1001
# argon2-cffi               20.1.0           py38haf1e3a3_1
# astunparse                1.6.3                    pypi_0    pypi
# async_generator           1.10                       py_0
# attrs                     20.3.0             pyhd3eb1b0_0
# backcall                  0.2.0                      py_0
# bleach                    3.2.2              pyhd3eb1b0_0
# brotlipy                  0.7.0           py38h9ed2024_1003
# bzip2                     1.0.8                hc929b4f_4    conda-forge
# c-ares                    1.17.1               hc929b4f_0    conda-forge
# ca-certificates           2021.1.19            hecd8cb5_0
# cachetools                4.2.0                    pypi_0    pypi
# ...
